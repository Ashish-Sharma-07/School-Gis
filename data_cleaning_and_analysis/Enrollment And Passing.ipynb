# %% [markdown]
# # Enrollment And Passing Percentage

# %% [markdown]
# ## Age Enrollmenent

# %%
# Getting the school codes of maharashtra
file_name = "/home/flash/Desktop/Basics.csv"
import pandas as pd
df = pd.DataFrame(data=None,columns=["SCHCD"],)
for chunk in pd.read_csv(file_name,chunksize=1000,iterator=True):
    df = df.append(chunk[["SCHCD"]],ignore_index=True)

# %%
df = df.infer_objects()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106495 entries, 0 to 106494
# Data columns (total 1 columns):
# SCHCD    106495 non-null int64
# dtypes: int64(1)
# memory usage: 832.1 KB

# %%
df.loc[:,["SCHCD"]]
# Out:
#               SCHCD
# 0       27150805401
# 1       27270905101
# 2       27270905401
# 3       27110313101
# 4       27150705801
# 5       27270801701
# 6       27270806101
# 7       27270908101
# 8       27151300312
# 9       27270901201
# 10      27270900101
# 11      27151310008
# 12      27151502008
# 13      27160208701
# 14      27160209801
# 15      27160309301
# 16      27160310701
# 17      27120722801
# 18      27160414501
# 19      27120716601
# 20      27160113701
# 21      27170303801
# 22      27170216101
# 23      27170210401
# 24      27170403501
# 25      27050121403
# 26      27310205001
# 27      27240101001
# 28      27240706501
# 29      27240705601
# ...             ...
# 106465  27260200106
# 106466  27260201201
# 106467  27261109023
# 106468  27260504501
# 106469  27260307307
# 106470  27260307604
# 106471  27060612342
# 106472  27060607101
# 106473  27110407604
# 106474  27260307403
# 106475  27260709001
# 106476  27260411501
# 106477  27260301001
# ...

# %%
# getting the school codes from age_enrollement

# %%
file_age = "/home/flash/Desktop/data_analysis/School_14-15/AGE_ENROLLMENT_2014-15.csv"

# %%
a = pd.DataFrame(data = [1,2,3,4],columns=['A'])

# %%
a
# Out:
#    A
# 0  1
# 1  2
# 2  3
# 3  4

# %%
b = pd.DataFrame(data=[3,5,6,4],columns=['A'])

# %%
b
# Out:
#    A
# 0  3
# 1  5
# 2  6
# 3  4

# %%
a[b['A']>=4]
# Out:
#    A
# 1  2
# 2  3
# 3  4
